# %% [markdown]
# nrslkv nlskrn vsknv

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt


img = mpimg.imread(r"D:\Datasets\Glycoma dataset 1 - 6gb\ORIGA\Masks\645.png")
plt.imshow(img)

# %%
img = mpimg.imread(r"D:\Datasets\Glycoma dataset 1 - 6gb\ORIGA\Masks\002.png")
plt.imshow(img)
